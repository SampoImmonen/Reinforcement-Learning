# %% [markdown]
# # notebook to sketch Logger class
# ## Class handless storing info, logging and plots
# ### Info coming in:
# 1. episode rewards
# 2. loss.item()
# 3. episode lengths
# 4. time
#
# ### things to calculate
# 1. mean reward of last n episodes.
# 2. mean loss
# 3. time elapsed
# 4. mean number of steps
# 5. amount of episodes completed by a parameter
#
# ### functionalities
# 1. saving model
# 2. plotting

# %%
# Out:
# (1.025787353515625, 6, 0.001432657241821289)
# (3.0755908489227295, 1, 0.002024412155151367)
# (1.185350775718689, 9, 0.002024412155151367)
# (1.1593540906906128, 3, 0.0030014514923095703)
# (1.137694239616394, 4, 0.004002571105957031)
# (1.4463624954223633, 5, 0.004002571105957031)
# (1.0149914026260376, 1, 0.0050013065338134766)
# (2.4268975257873535, 6, 0.0050013065338134766)
# (1.2904223203659058, 1, 0.006000995635986328)
# (1.6834057569503784, 3, 0.006000995635986328)
# 10 episodes played, mean reward:1.544585680961609, mean ep length:3.9, time elapsed:0.006000995635986328
# episodes completed: 2
# new best average
# (1.230950117111206, 9, 0.0070018768310546875)
# (2.954958915710449, 8, 0.008002996444702148)
# (1.409031629562378, 5, 0.008002996444702148)
# (1.1023503541946411, 1, 0.008002996444702148)
# (1.7084922790527344, 1, 0.009003639221191406)
# (2.553192615509033, 6, 0.009003639221191406)
# (1.914848804473877, 4, 0.010001182556152344)
# ...

# %%
from logger import Logger


run_config = {
    'env' : 'PongNoFrameskip-v4',
    'frameskip' : 4,
    'lr' : 0.0001,
    'batch_size' : 32,
    'train_threshold': 10000,
    'buffer_capacity': 100000,
    'gamma' : 0.99,
    'n_steps':3,
    'device': 'cuda',
    'step_interval': 2,
    'log_interval': 10,
    'sync_interval': 10,
    'doubleQ': False,
    'log_dir' : '',
    'dueling': True
}
# Out:
# Help on class Logger in module logger:
#
# class Logger(builtins.object)
#  |  Logger(save_dir, interval, best_reward=0, complete_limit=None, stop_limit=None)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, save_dir, interval, best_reward=0, complete_limit=None, stop_limit=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  push_episode(self, episode, net)
#  |
#  |  push_loss(self, loss)
#  |      input has to be loss.item() other wise computational graph if stored
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
