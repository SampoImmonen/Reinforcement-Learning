# %% [markdown]
# # Prototyping DreamerV2
# ## Mastering Atari with Discrete World Models (https://arxiv.org/abs/2010.02193)
#
#
# ![Dreamerperformance.PNG](attachment:Dreamerperformance.PNG)

# %% [markdown]
# ![DreamerModel.PNG](attachment:DreamerModel.PNG)

# %% [markdown]
# # Dreamer Notes:
# 1. Earlier version https://arxiv.org/pdf/1912.01603.pdf
# 2. World Model based on https://arxiv.org/pdf/1811.04551.pdf
# 3. Learn compact categorical latent variables to represent world
# 4. code for original https://github.com/danijar/dreamerv2
# ![experiencedataset.PNG](attachment:experiencedataset.PNG)
# 5. google ai blog https://ai.googleblog.com/2021/02/mastering-atari-with-discrete-world.html

# %% [markdown]
# ![modelcomponents.PNG](attachment:modelcomponents.PNG)

# %% [markdown]
# ![RSSm.PNG](attachment:RSSm.PNG)

# %% [markdown]
# ![rssm2.PNG](attachment:rssm2.PNG)

# %% [markdown]
# # Phases
#
# 1. training world model given an actor
#     1. collect Data sequences
#
# 2. Training actor and critic given a world model
#     1. generate sequences of hidden states
#
#
#
# # Data generation
# 1. collect sequences of  tuples (image, action, reward, discount factor)
# 2. a training sample is a sequence of 50 tuples
